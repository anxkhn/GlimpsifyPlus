# %%
from pathlib import Path
from typing import Optional

import pandas as pd

prominent_peak_report_path = "/home/vedant/Desktop/glimpsify/most_info_frame_extractor/experiments/28/evaluation_report.csv"
k_transactions_report_path = "/home/vedant/Desktop/glimpsify/most_info_frame_extractor/experiments/28/evaluation_report_k_trans_v3.csv"
comparison_report_path = "/home/vedant/Desktop/glimpsify/most_info_frame_extractor/experiments/29/comparison_report_peak_vs_k_trans.csv"

Path(comparison_report_path).parent.mkdir(parents=True, exist_ok=True)


def remove_outliers(df, col, suffix: Optional[str] = None):
    if not suffix:
        suffix = ""

    Q1 = df[col + suffix].quantile(0.25)
    Q3 = df[col + suffix].quantile(0.75)
    IQR = Q3 - Q1

    multiplier = 1
    lower_bound = Q1 - multiplier * IQR
    upper_bound = Q3 + multiplier * IQR
    df = df[(df[col + suffix] >= lower_bound) & (df[col + suffix] <= upper_bound)]
    return df


def compare_extraction_strategies(path1: str, path2: str, lsuffix="_first", rsuffix="_second", should_remove_outliers=False):
    df1 = pd.read_csv(path1)
    df2 = pd.read_csv(path2)

    if should_remove_outliers:
        df1 = remove_outliers(df1, "similarity_score")
        df2 = remove_outliers(df2, "similarity_score")

    df1.set_index("internal_id", inplace=True)
    df2.set_index("internal_id", inplace=True)

    comparison_df = df1.join(df2, lsuffix=lsuffix, rsuffix=rsuffix, how="inner")
    comparison_df["similarity_score_result"] = comparison_df.apply(
        lambda x: x["similarity_score" + lsuffix] > x["similarity_score" + rsuffix], axis=1)

    new_col_arrangement = []
    cols = df1.columns
    for col in cols:
        new_col_arrangement.extend([col + lsuffix, col + rsuffix])
    comparison_df = comparison_df[new_col_arrangement]

    return comparison_df

# %%
comparison_df = compare_extraction_strategies(prominent_peak_report_path, k_transactions_report_path,
                                              lsuffix="_prominent_peaks", rsuffix="_k_transactions", should_remove_outliers=False)
comparison_df.head()
# Out:
#                             generated_pdf_path_prominent_peaks  \
# internal_id
# lhopxd       /home/vedant/Downloads/key-frame-extraction-re...
# wayvbl       /home/vedant/Downloads/key-frame-extraction-re...
# ruweka       /home/vedant/Downloads/key-frame-extraction-re...
# sgmaal       /home/vedant/Downloads/key-frame-extraction-re...
# bmqioa       /home/vedant/Downloads/key-frame-extraction-re...
#
#                              generated_pdf_path_k_transactions  \
# internal_id
# lhopxd       /home/vedant/Desktop/glimpsify/most_info_frame...
# wayvbl       /home/vedant/Desktop/glimpsify/most_info_frame...
# ruweka       /home/vedant/Desktop/glimpsify/most_info_frame...
# sgmaal       /home/vedant/Desktop/glimpsify/most_info_frame...
# bmqioa       /home/vedant/Desktop/glimpsify/most_info_frame...
#
#                             reference_pdf_path_prominent_peaks  \
# internal_id
# lhopxd       /home/vedant/Downloads/reference-pdfs-v1/lhopx...
# wayvbl       /home/vedant/Downloads/reference-pdfs-v1/wayvb...
# ruweka       /home/vedant/Downloads/reference-pdfs-v1/ruwek...
# sgmaal       /home/vedant/Downloads/reference-pdfs-v1/sgmaa...
# bmqioa       /home/vedant/Downloads/reference-pdfs-v1/bmqio...
#
#                              reference_pdf_path_k_transactions  \
# internal_id
# lhopxd       /home/vedant/Downloads/reference-pdfs-v1/lhopx...
# wayvbl       /home/vedant/Downloads/reference-pdfs-v1/wayvb...
# ruweka       /home/vedant/Downloads/reference-pdfs-v1/ruwek...
# sgmaal       /home/vedant/Downloads/reference-pdfs-v1/sgmaa...
# bmqioa       /home/vedant/Downloads/reference-pdfs-v1/bmqio...
#
#              num_of_duplicates_prominent_peaks  \
# internal_id
# lhopxd                                       0
# wayvbl                                      54
# ruweka                                       0
# sgmaal                                       0
# bmqioa                                       0
#
#              num_of_duplicates_k_transactions  \
# internal_id
# lhopxd                                      0
# wayvbl                                      0
# ruweka                                      0
# sgmaal                                      0
# bmqioa                                      0
#
#              num_of_missing_key_frames_prominent_peaks  \
# internal_id
# lhopxd                                               3
# wayvbl                                              20
# ruweka                                               4
# sgmaal                                               6
# bmqioa                                               3
#
#              num_of_missing_key_frames_k_transactions  \
# internal_id
# lhopxd                                              3
# wayvbl                                             39
# ruweka                                              4
# sgmaal                                              8
# bmqioa                                              3
#
#              num_of_non_key_frames_prominent_peaks  \
# internal_id
# lhopxd                                           1
# wayvbl                                          61
# ruweka                                           6
# sgmaal                                           2
# bmqioa                                           0
#
#              num_of_non_key_frames_k_transactions  \
# internal_id
# lhopxd                                          1
# wayvbl                                         20
# ruweka                                          6
# sgmaal                                          2
# bmqioa                                          0
#
#              generated_pdf_key_frame_count_prominent_peaks  \
# internal_id
# lhopxd                                                   9
# wayvbl                                                 145
# ruweka                                                   8
# sgmaal                                                  13
# bmqioa                                                   7
#
#              generated_pdf_key_frame_count_k_transactions  \
# internal_id
# lhopxd                                                  9
# wayvbl                                                 31
# ruweka                                                  8
# sgmaal                                                 11
# bmqioa                                                  7
#
#              reference_pdf_key_frame_count_prominent_peaks  \
# internal_id
# lhopxd                                                  11
# wayvbl                                                  50
# ruweka                                                   6
# sgmaal                                                  17
# bmqioa                                                  10
#
#              reference_pdf_key_frame_count_k_transactions  \
# internal_id
# lhopxd                                                 11
# wayvbl                                                 50
# ruweka                                                  6
# sgmaal                                                 17
# bmqioa                                                 10
#
#              accuracy_prominent_peaks  accuracy_k_transactions  \
# internal_id
# lhopxd                       0.727273                 0.727273
# wayvbl                       0.600000                 0.220000
# ruweka                       0.333333                 0.333333
# sgmaal                       0.647059                 0.529412
# bmqioa                       0.700000                 0.700000
#
#              similarity_score_prominent_peaks  similarity_score_k_transactions
# internal_id
# lhopxd                               0.666667                         0.666667
# wayvbl                               0.270270                         0.157143
# ruweka                               0.166667                         0.166667
# sgmaal                               0.578947                         0.473684
# bmqioa                               0.700000                         0.700000

# %%
comparison_df.to_csv(comparison_report_path)

# %%
comparison_df.describe()
# Out:
#        num_of_duplicates_prominent_peaks  num_of_duplicates_k_transactions  \
# count                          88.000000                         88.000000
# mean                            4.250000                          0.727273
# std                            10.500411                          1.161917
# min                             0.000000                          0.000000
# 25%                             0.000000                          0.000000
# 50%                             1.000000                          0.000000
# 75%                             2.000000                          1.000000
# max                            54.000000                          7.000000
#
#        num_of_missing_key_frames_prominent_peaks  \
# count                                  88.000000
# mean                                   10.818182
# std                                    10.802879
# min                                     1.000000
# 25%                                     4.000000
# 50%                                     7.500000
# 75%                                    12.250000
# max                                    65.000000
#
#        num_of_missing_key_frames_k_transactions  \
# count                                 88.000000
# mean                                  13.931818
# std                                   13.828004
# min                                    0.000000
# 25%                                    4.750000
# 50%                                    9.000000
# 75%                                   17.250000
# max                                   79.000000
#
#        num_of_non_key_frames_prominent_peaks  \
# count                              88.000000
# mean                                8.056818
# std                                14.501176
# min                                 0.000000
# 25%                                 1.000000
# 50%                                 3.500000
# 75%                                10.000000
# max                               111.000000
#
#        num_of_non_key_frames_k_transactions  \
# count                             88.000000
# mean                               3.965909
# std                                3.448967
# min                                0.000000
# 25%                                1.000000
# 50%                                3.000000
# 75%                                6.000000
# max                               20.000000
#
#        generated_pdf_key_frame_count_prominent_peaks  \
# count                                      88.000000
# mean                                       23.136364
# std                                        27.640210
# min                                         2.000000
# 25%                                         7.000000
# 50%                                        13.000000
# 75%                                        24.500000
# max                                       145.000000
#
#        generated_pdf_key_frame_count_k_transactions  \
# count                                     88.000000
# mean                                      12.409091
# std                                        6.426662
# min                                        3.000000
# 25%                                        8.000000
# 50%                                       10.000000
# 75%                                       14.250000
# max                                       34.000000
#
#        reference_pdf_key_frame_count_prominent_peaks  \
# count                                      88.000000
# mean                                       21.647727
# std                                        17.928363
# min                                         1.000000
# 25%                                        10.000000
# 50%                                        15.000000
# 75%                                        27.250000
# max                                       105.000000
#
#        reference_pdf_key_frame_count_k_transactions  accuracy_prominent_peaks  \
# count                                     88.000000                 88.000000
# mean                                      21.647727                  0.505343
# std                                       17.928363                  0.175364
# min                                        1.000000                  0.000000
# 25%                                       10.000000                  0.402056
# 50%                                       15.000000                  0.518445
# 75%                                       27.250000                  0.629464
# max                                      105.000000                  0.897436
#
#        accuracy_k_transactions  similarity_score_prominent_peaks  \
# count                88.000000                         88.000000
# mean                  0.424861                          0.402814
# std                   0.176754                          0.156656
# min                   0.000000                          0.000000
# 25%                   0.307692                          0.291429
# 50%                   0.410428                          0.403704
# 75%                   0.538462                          0.500000
# max                   1.000000                          0.833333
#
#        similarity_score_k_transactions
# count                        88.000000
# mean                          0.350483
# std                           0.156429
# min                           0.000000
# 25%                           0.237782
# 50%                           0.333333
# 75%                           0.457576
# max                           0.833333
