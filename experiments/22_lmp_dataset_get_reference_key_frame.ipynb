# %%
from collections import defaultdict
from pathlib import Path
from pytubefix import YouTube

# %%
base_folder = r"/media/vedant/New Volume/DPythonProjects/yt_summarizer/experiments/data_oct"

# %%
base_folder = Path(base_folder)

# %%
csv_files = list(base_folder.rglob("*.csv"))
csv_files
# Out:
# [PosixPath('/media/vedant/New Volume/DPythonProjects/yt_summarizer/experiments/data_oct/figure_annotations.csv'),
#  PosixPath('/media/vedant/New Volume/DPythonProjects/yt_summarizer/experiments/data_oct/lecture_vids.csv'),
#  PosixPath('/media/vedant/New Volume/DPythonProjects/yt_summarizer/experiments/data_oct/raw_video_links.csv'),
#  PosixPath('/media/vedant/New Volume/DPythonProjects/yt_summarizer/experiments/data_oct/anat-1/AnatomyPhysiology/01/slide_020_trace.csv'),
#  PosixPath('/media/vedant/New Volume/DPythonProjects/yt_summarizer/experiments/data_oct/anat-1/AnatomyPhysiology/01/slide_021_ocr.csv'),
#  PosixPath('/media/vedant/New Volume/DPythonProjects/yt_summarizer/experiments/data_oct/anat-1/AnatomyPhysiology/01/slide_021_spoken.csv'),
#  PosixPath('/media/vedant/New Volume/DPythonProjects/yt_summarizer/experiments/data_oct/anat-1/AnatomyPhysiology/01/slide_021_trace.csv'),
# ...

# %%
from collections import defaultdict

# %%
csv_file_categories = set()

# %%
for csv_file in csv_files:
    file_name = csv_file.stem
    category = file_name.split("_")[-1]
    csv_file_categories.add(category)

# %%
list(csv_file_categories)
# Out:
# ['ocr',
#  'annotations',
#  'trace',
#  'transcripts',
#  'single',
#  'spoken',
#  'vids',
#  'links']

# %%
raw_video_links = "/home/vedant/Downloads/lpmdata_102023/data_oct/raw_video_links.csv"

# %%
import pandas as pd

# %%
df = pd.read_csv(raw_video_links)

# %%
df.head()
# Out:
#    Unnamed: 0                               Answer.startTimeList  seconds  \
# 0         309  Start Time|5.4833|34.9833|101.9833|165.4833|23...   250.27
# 1         210  Start Time|30.3946|55.0392|157.0121|542.5121|7...  4130.41
# 2          49  Start Time|24.9610|70.2913|107.3214|145.5609|1...  2289.09
# 3         127  Start Time|32.3223|48.3223|95.8223|258.6495|27...  1643.51
# 4          89  Start Time|6|34|157.9999|280.9999|347.4999|411...  3171.08
#
#     speaker         video_id                                  youtube_url  \
# 0    dental  _8xHh1tk7jY.mp4  https://www.youtube.com/watch?v=_8xHh1tk7jY
# 1  speaking  _Awekr6-ilg.mp4  https://www.youtube.com/watch?v=_Awekr6-ilg
# 2     bio-4  _BvFr9HEiQg.mp4  https://www.youtube.com/watch?v=_BvFr9HEiQg
# 3    dental  _e_B8rTl_rU.mp4  https://www.youtube.com/watch?v=_e_B8rTl_rU
# 4     bio-4  _Jw3DQ7_pxg.mp4  https://www.youtube.com/watch?v=_Jw3DQ7_pxg
#
#   learning_objectives
# 0                none
# 1       slide_002.jpg
# ...

# %%
timestamps = list(map(float, df.iloc[0]["Answer.startTimeList"].split("|")[1:]))

# %%
from pytubefix import YouTube

# %%
video_id = df.iloc[0]["video_id"][:-4]
video_id
# Out:
# '_8xHh1tk7jY'

# %%
video = YouTube.from_id(video_id)
video.title
# Out:
# 'Oral Pathology | Salivary Gland Benign Diseases | INBDE, ADAT'

# %%
video.watch_url + f"&t={round(timestamps[3])}"
# Out:
# 'https://youtube.com/watch?v=_8xHh1tk7jY&t=165'

# %%
videos = []
for i in video_ids:
    try:
        yt = YouTube.from_id(i)
        videos.append(yt)
    except Exception as e:
        print(e)
        print(i)
        continue
videos
# Out:
# [<pytubefix.__main__.YouTube object: videoId=IIfeX44RI9k>,
#  <pytubefix.__main__.YouTube object: videoId=_yre2uKcj7A>,
#  <pytubefix.__main__.YouTube object: videoId=EQQLej9EoTY>,
#  <pytubefix.__main__.YouTube object: videoId=LQ7IXyQSXBk>,
#  <pytubefix.__main__.YouTube object: videoId=SYrdGRPIGms>,
#  'https://youtube.com/watch?v=ALRJCeVT0fQ',
#  'https://youtube.com/watch?v=KDVP_WAIUXs',
#  'https://youtube.com/watch?v=AMwWMcncTmQ',
#  'https://youtube.com/watch?v=WqBw1n4u4gU',
#  'https://youtube.com/watch?v=CmION0EvzLc',
#  'https://youtube.com/watch?v=w9milH9QNhY',
#  'https://youtube.com/watch?v=VHbgjb4AV9U',
#  'https://youtube.com/watch?v=JLVt1iAJJts',
#  'https://youtube.com/watch?v=zB08AVntCUc',
#  'https://youtube.com/watch?v=9GmySN5P408',
#  'https://youtube.com/watch?v=hgk8-2Fweb8',
# ...

# %%
for i in video_urls:
    print(i)
# Out:
# https://youtube.com/watch?v=1gB90u2JOYg
# https://youtube.com/watch?v=g1JIbOMWBBM
# https://youtube.com/watch?v=gsDGPyBzrQM
# https://youtube.com/watch?v=y5KMF4sUHEg
# https://youtube.com/watch?v=UjT_8kOnITE
# https://youtube.com/watch?v=XqzL4f6L_Fo
# https://youtube.com/watch?v=fwdxieyNbWM
# https://youtube.com/watch?v=lIKsYXHp0lU
# https://youtube.com/watch?v=O4QBTXeWmBc
# https://youtube.com/watch?v=SfCj6FLCGPM
# https://youtube.com/watch?v=ALRJCeVT0fQ
# https://youtube.com/watch?v=KDVP_WAIUXs
# https://youtube.com/watch?v=AMwWMcncTmQ
# https://youtube.com/watch?v=WqBw1n4u4gU
# https://youtube.com/watch?v=CmION0EvzLc
# https://youtube.com/watch?v=w9milH9QNhY
# https://youtube.com/watch?v=VHbgjb4AV9U
# https://youtube.com/watch?v=JLVt1iAJJts
# https://youtube.com/watch?v=zB08AVntCUc
# https://youtube.com/watch?v=9GmySN5P408
# https://youtube.com/watch?v=hgk8-2Fweb8
# https://youtube.com/watch?v=cwqr460lHLw
# https://youtube.com/watch?v=QA-Td5Kvjqk
# ...

# %%
transcription_file = r"/media/vedant/New Volume/DPythonProjects/yt_summarizer/experiments/data_oct/psy-1/LectureSeriesForIntrotoPsy-PSY101/1/j2-9yymHfeU_transcripts.csv"

# %%
transcription_file = Path(transcription_file)

# %%
video_id = transcription_file.stem.split("_")[0]
video_id
# Out:
# 'j2-9yymHfeU'

# %%
from pytubefix import YouTube

# %%
video = YouTube.from_id(video_id)

# %%
# !export PYTHONPATH="/media/vedant/New Volume/DPythonProjects/yt_summarizer"

# %%
import os

os.environ["PYTHONPATH"] = "/media/vedant/New Volume/DPythonProjects/yt_summarizer"

# %%
import pytubefix

pytubefix.__version__
# Out:
# '8.12.3'

# %%
# download_youtube_video(video.watch_url, "./data")

# %%
playlist_url = "https://www.youtube.com/watch?v=1gB90u2JOYg&list=TLGGMVNkwos0TeAwMzA1MjAyNQ"
playlist_id = playlist_url.split("=")[-1]
playlist_id
# Out:
# 'TLGGMVNkwos0TeAwMzA1MjAyNQ'

# %%
formatted_playlist_url = f"https://www.youtube.com/playlist?list={playlist_id}"

# %%
formatted_playlist_url
# Out:
# 'https://www.youtube.com/playlist?list=TLGGMVNkwos0TeAwMzA1MjAyNQ'
